# %%
from imageai.Prediction import ImagePrediction

# %%
import os

# %%
execution_path = os.getcwd()

# %% [markdown]
# # Here we use - ResNet50 by Microsoft Research (Size = 98 mb, fast prediction time and high accuracy) , model file should be downloaded in advance.
# ![img1.jpg](attachment:img1.jpg)

# %%
prediction = ImagePrediction()
prediction.setModelTypeAsResNet()
prediction.setModelPath(os.path.join(execution_path, "resnet50_weights_tf_dim_ordering_tf_kernels.h5"))
prediction.loadModel()

# choose top 5 likely results
predictions, probabilities = prediction.predictImage(os.path.join(execution_path, "img1.jpg"), result_count=5 )
for eachPrediction, eachProbability in zip(predictions, probabilities):
    print(eachPrediction , " : " , eachProbability)
# Out:
# cardigan  :  91.30910038948059
# stole  :  4.195530340075493
# bonnet  :  0.9958759881556034
# wool  :  0.8504630997776985
# fur_coat  :  0.5948598496615887

# %% [markdown]
# Now, try to predict multiple images
# ![img1.jpg](attachment:img1.jpg)
# ![img2.jpeg](attachment:img2.jpeg)
# ![img3.jpg](attachment:img3.jpg)

# %%
# predict a set of images
multiple_prediction = ImagePrediction()
multiple_prediction.setModelTypeAsResNet()
multiple_prediction.setModelPath(os.path.join(execution_path, "resnet50_weights_tf_dim_ordering_tf_kernels.h5"))
multiple_prediction.loadModel()

all_images_array = []

all_files = os.listdir(execution_path)
for each_file in all_files:
    if(each_file.endswith(".jpg") or each_file.endswith(".jpeg")):
        all_images_array.append(each_file)

results_array = multiple_prediction.predictMultipleImages(all_images_array, result_count_per_image=5)

for each_result in results_array:
    predictions, percentage_probabilities = each_result["predictions"], each_result["percentage_probabilities"]
    for index in range(len(predictions)):
        print(predictions[index] + " : " + str(percentage_probabilities[index]))
    print("-----------------------")
# Out:
# cardigan : 91.30910038948059
# stole : 4.195530340075493
# bonnet : 0.9958759881556034
# wool : 0.8504630997776985
# fur_coat : 0.5948598496615887
# -----------------------
# rapeseed : 18.913395702838898
# minivan : 8.979189395904541
# car_mirror : 8.828253298997879
# picket_fence : 2.767675556242466
# lakeside : 2.461925707757473
# -----------------------
# bustard : 52.03372240066528
# vulture : 20.936208963394165
# crane : 10.620462894439697
# kite : 10.205284506082535
# white_stork : 1.647203229367733
# -----------------------
